# %% [markdown]
# # Problem 3

# %%
#Import libraries. Use scipys sparse for better computational time. 
from scipy.sparse import diags
import scipy.sparse as sp
import scipy.sparse.linalg as sl
import numpy as np
import matplotlib.pyplot as plt
import scipy.interpolate
import scipy.integrate
from numba import jit
from numpy.linalg import norm
import time
from mpl_toolkits import mplot3d

#Run some of our libraries. First file has to be in same folder as this file. Second has a folder specified.
#The functions in these files are used a lot here, so they need to be imported for anything to work.
# %run Problem_3_fnc.ipynb 
# %run ../Utilities/Utilities.ipynb 

#Display options. Change these after preference
# Use this instead of inline for pop-up plots: %matplotlib qt 
# %matplotlib inline
np.set_printoptions(linewidth=600, precision=2) #Printoptions for debugging and displaying matricies.

# %% [markdown]
# ## Plots of the Analytic and Numerical Solutions

# %%
#Obtain numerical and analytic solution
numericalSolution, xaxis, yaxis = fivePointFormula(200, 200, boundaryfnc)
analyticSolution = solutionfnc(xaxis,yaxis)

# %%
#Plot the numerical solution. Figure 3.2
plot3D(numericalSolution, xaxis, yaxis, zlim=(-1,1), zlabel ="$U(x,y)$")

# %%
#Plot the analytic solution. Figure 3.1
plot3D(analyticSolution, xaxis, yaxis, zlim=(-1,1), zlabel ="$u(x,y)$")

# %%
#Plot the difference between the analytic and numerical solution. Figure 3.3
plot3D(numericalSolution-analyticSolution, xaxis, yaxis)

# %% [markdown]
# ## Convergence Plots

# %%
#Make an error plot along the x-axis. The indecies are powers of 10. M_y = 2*max(M_x)=2*1000. Figure 3.4
errorPlots(x=True, startIndex=1, endIndex=3, evaluationPoints = 5, expectedOrder = 2)

# %%
#Make an error plot along the y-axis. M_x = 2*max(M_y)=2*1000. Figure 3.5
errorPlots(x=False, startIndex = 1, endIndex = 3, evaluationPoints = 5, expectedOrder = 2)
# Out:
# /Users/MarkusTraetli/anaconda3/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:145: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)

# %%
#Make an error plot with Mx=My plotted against degrees of freedom M_x*M_y. Figure 3.6
errorPlots(both=True, startIndex=1, endIndex=3, evaluationPoints = 5, expectedOrder = 1)
# Out:
# /Users/MarkusTraetli/anaconda3/lib/python3.6/site-packages/scipy/sparse/linalg/dsolve/linsolve.py:145: SparseEfficiencyWarning: spsolve requires A be CSC or CSR matrix format
#   SparseEfficiencyWarning)
